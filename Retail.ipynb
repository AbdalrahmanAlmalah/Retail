# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df=pd.read_csv('SampleSuperstore.csv')
df.head()
# Out:
#         Ship Mode    Segment        Country             City       State  \
# 0    Second Class   Consumer  United States        Henderson    Kentucky
# 1    Second Class   Consumer  United States        Henderson    Kentucky
# 2    Second Class  Corporate  United States      Los Angeles  California
# 3  Standard Class   Consumer  United States  Fort Lauderdale     Florida
# 4  Standard Class   Consumer  United States  Fort Lauderdale     Florida
#
#    Postal Code Region         Category Sub-Category     Sales  Quantity  \
# 0        42420  South        Furniture    Bookcases  261.9600         2
# 1        42420  South        Furniture       Chairs  731.9400         3
# 2        90036   West  Office Supplies       Labels   14.6200         2
# 3        33311  South        Furniture       Tables  957.5775         5
# 4        33311  South  Office Supplies      Storage   22.3680         2
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.00    6.8714
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Ship Mode     9994 non-null   object
#  1   Segment       9994 non-null   object
#  2   Country       9994 non-null   object
#  3   City          9994 non-null   object
#  4   State         9994 non-null   object
#  5   Postal Code   9994 non-null   int64
#  6   Region        9994 non-null   object
#  7   Category      9994 non-null   object
#  8   Sub-Category  9994 non-null   object
#  9   Sales         9994 non-null   float64
#  10  Quantity      9994 non-null   int64
#  11  Discount      9994 non-null   float64
#  12  Profit        9994 non-null   float64
# dtypes: float64(3), int64(2), object(8)
# memory usage: 1015.1+ KB

# %%
df.plot.line(x='Sales', y='Profit')
plt.title('Line Plot of Sales vs. Profit')
plt.xlabel('Sales')
plt.ylabel('Profit')
plt.show()

# %%
df_ = df[['Profit', 'Discount']]

# %%
df_.corr()
# Out:
#             Profit  Discount
# Profit    1.000000 -0.219487
# Discount -0.219487  1.000000

# %%
cities = df['City'].tolist()  # Extract city names as a list
sales = df['Sales'].tolist()  # Extract sales values as a list

# Create a bar chart
plt.bar(cities, sales)  # Cities on x-axis, sales on y-axis

# Customize the plot
plt.xlabel('City')
plt.ylabel('Sales')
plt.title('City Sales')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.tight_layout()  # Adjust spacing for better visualization

plt.show()

# %%
cities = df['Region'].tolist()  # Extract city names as a list
sales = df['Sales'].tolist()  # Extract sales values as a list

# Create a bar chart
plt.bar(cities, sales)  # Cities on x-axis, sales on y-axis

# Customize the plot
plt.xlabel('Region')
plt.ylabel('Sales')
plt.title('Region Sales')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.tight_layout()  # Adjust spacing for better visualization

plt.show()

# %%
cities = df['Ship Mode'].tolist()  # Extract city names as a list
sales = df['Sales'].tolist()  # Extract sales values as a list

# Create a bar chart
plt.bar(cities, sales)  # Cities on x-axis, sales on y-axis

# Customize the plot
plt.xlabel('Ship Mode')
plt.ylabel('Sales')
plt.title('Ship Mode Sales')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.tight_layout()  # Adjust spacing for better visualization

plt.show()

# %%
cities = df['Ship Mode'].tolist()  # Extract city names as a list
sales = df['Profit'].tolist()  # Extract sales values as a list

# Create a bar chart
plt.bar(cities, sales)  # Cities on x-axis, sales on y-axis

# Customize the plot
plt.xlabel('Ship Mode')
plt.ylabel('Profit')
plt.title('Ship Mode Profit')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.tight_layout()  # Adjust spacing for better visualization

plt.show()

# %%
cities = df['Category'].tolist()  # Extract city names as a list
sales = df['Profit'].tolist()  # Extract sales values as a list

# Create a bar chart
plt.bar(cities, sales)  # Cities on x-axis, sales on y-axis

# Customize the plot
plt.xlabel('Category')
plt.ylabel('Profit')
plt.title('Category Profit')
plt.xticks(rotation=45)  # Rotate x-axis labels for better readability
plt.tight_layout()  # Adjust spacing for better visualization

plt.show()

# %%
print(df.columns)
# Out:
# Index(['Ship Mode', 'Segment', 'Country', 'City', 'State', 'Postal Code',
#        'Region', 'Category', 'Sub-Category', 'Sales', 'Quantity', 'Discount',
#        'Profit'],
#       dtype='object')

# %%
df_new=df[["Ship Mode","City","Region","Category",'Sales',"Quantity","Discount","Profit"]]
df_new.head()
# Out:
#         Ship Mode             City Region         Category     Sales  \
# 0    Second Class        Henderson  South        Furniture  261.9600
# 1    Second Class        Henderson  South        Furniture  731.9400
# 2    Second Class      Los Angeles   West  Office Supplies   14.6200
# 3  Standard Class  Fort Lauderdale  South        Furniture  957.5775
# 4  Standard Class  Fort Lauderdale  South  Office Supplies   22.3680
#
#    Quantity  Discount    Profit
# 0         2      0.00   41.9136
# 1         3      0.00  219.5820
# 2         2      0.00    6.8714
# 3         5      0.45 -383.0310
# 4         2      0.20    2.5164

# %%
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import OneHotEncoder

# %%
e1 = OneHotEncoder(sparse=False)
res1= e1.fit_transform(df_new[['Ship Mode']])
df_new = pd.get_dummies(df_new, columns=['Ship Mode'])
df_new
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
#                  City Region         Category     Sales  Quantity  Discount  \
# 0           Henderson  South        Furniture  261.9600         2      0.00
# 1           Henderson  South        Furniture  731.9400         3      0.00
# 2         Los Angeles   West  Office Supplies   14.6200         2      0.00
# 3     Fort Lauderdale  South        Furniture  957.5775         5      0.45
# 4     Fort Lauderdale  South  Office Supplies   22.3680         2      0.20
# ...               ...    ...              ...       ...       ...       ...
# 9989            Miami  South        Furniture   25.2480         3      0.20
# 9990       Costa Mesa   West        Furniture   91.9600         2      0.00
# ...

# %%
e2 = OneHotEncoder(sparse=False)
res2= e2.fit_transform(df_new[['Region']])
df_new = pd.get_dummies(df_new, columns=['Region'])
df_new
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
#                  City         Category     Sales  Quantity  Discount  \
# 0           Henderson        Furniture  261.9600         2      0.00
# 1           Henderson        Furniture  731.9400         3      0.00
# 2         Los Angeles  Office Supplies   14.6200         2      0.00
# 3     Fort Lauderdale        Furniture  957.5775         5      0.45
# 4     Fort Lauderdale  Office Supplies   22.3680         2      0.20
# ...               ...              ...       ...       ...       ...
# 9989            Miami        Furniture   25.2480         3      0.20
# 9990       Costa Mesa        Furniture   91.9600         2      0.00
# 9991       Costa Mesa       Technology  258.5760         2      0.20
# ...

# %%
e3 = OneHotEncoder(sparse=False)
res3= e3.fit_transform(df_new[['Category']])
df_new = pd.get_dummies(df_new, columns=['Category'])
df_new
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
#                  City     Sales  Quantity  Discount    Profit  \
# 0           Henderson  261.9600         2      0.00   41.9136
# 1           Henderson  731.9400         3      0.00  219.5820
# 2         Los Angeles   14.6200         2      0.00    6.8714
# 3     Fort Lauderdale  957.5775         5      0.45 -383.0310
# 4     Fort Lauderdale   22.3680         2      0.20    2.5164
# ...               ...       ...       ...       ...       ...
# 9989            Miami   25.2480         3      0.20    4.1028
# 9990       Costa Mesa   91.9600         2      0.00   15.6332
# 9991       Costa Mesa  258.5760         2      0.20   19.3932
# 9992       Costa Mesa   29.6000         4      0.00   13.3200
# ...

# %%
e4 = OneHotEncoder(sparse=False)
res4= e4.fit_transform(df_new[['City']])
df_new = pd.get_dummies(df_new, columns=['City'])
df_new
# Out:
# /usr/local/lib/python3.10/dist-packages/sklearn/preprocessing/_encoders.py:868: FutureWarning: `sparse` was renamed to `sparse_output` in version 1.2 and will be removed in 1.4. `sparse_output` is ignored unless you leave `sparse` to its default value.
#   warnings.warn(
#          Sales  Quantity  Discount    Profit  Ship Mode_First Class  \
# 0     261.9600         2      0.00   41.9136                  False
# 1     731.9400         3      0.00  219.5820                  False
# 2      14.6200         2      0.00    6.8714                  False
# 3     957.5775         5      0.45 -383.0310                  False
# 4      22.3680         2      0.20    2.5164                  False
# ...        ...       ...       ...       ...                    ...
# 9989   25.2480         3      0.20    4.1028                  False
# 9990   91.9600         2      0.00   15.6332                  False
# 9991  258.5760         2      0.20   19.3932                  False
# ...

# %%
from sklearn.model_selection import train_test_split

X_train , X_test, y_train , y_test = train_test_split(X, y, test_size = 0.2)

# %%
from sklearn import linear_model
clf = linear_model.LinearRegression()
clf.fit(X_train,y_train)
y_predict = clf.predict(X_test)
y_predict
# Out:
# array([  6.9088, 157.0176,  -2.2896, ...,   0.5998,  21.7728,   7.209 ])

# %%
print('multiple linear model coeff (w)', clf.coef_)
print('multiple linear model intercept (b)' , clf.intercept_)
print('R-squared score (training)', clf.score(X_train, y_train))
print('R-squared score (test)', clf.score(X_test,y_test))
# Out:
# multiple linear model coeff (w) [ 5.13826332e-18 -2.43138842e-14  4.46558589e-13  1.00000000e+00
#  -9.24602700e-05 -9.24602701e-05 -9.24602700e-05 -9.24602701e-05
#  -1.44168404e-04 -1.44168404e-04 -1.44168404e-04 -1.44168404e-04
#   7.98759171e-05  7.98759171e-05  7.98759171e-05 -9.86900284e-07
#  -9.86900568e-07 -9.86900492e-07 -9.86900503e-07 -9.86900402e-07
#  -9.86900561e-07 -9.86900575e-07 -9.86900387e-07 -9.86900436e-07
#  -9.86900526e-07 -9.86900480e-07 -9.86900551e-07 -9.86900379e-07
#  -9.86900427e-07 -9.86900551e-07 -9.86902286e-07 -9.86900569e-07
#  -1.06403999e-04 -9.86900517e-07 -9.86900517e-07 -9.86900513e-07
#  -9.86900489e-07 -9.86900506e-07 -9.86900497e-07 -9.86900507e-07
#  -9.86900512e-07 -9.86900504e-07 -9.86900513e-07 -9.86900507e-07
#  -9.86900504e-07 -9.86900526e-07 -9.86900518e-07 -9.86900501e-07
#  -9.86900509e-07 -9.86900500e-07 -9.86900511e-07 -9.86900514e-07
#  -9.86900462e-07 -9.86900514e-07 -9.86900476e-07 -2.45121363e-05
# ...

# %%
from sklearn.tree import DecisionTreeRegressor
from sklearn.linear_model import LinearRegression
clf = DecisionTreeRegressor()
clf.fit(X_train , y_train)
# Out:
# DecisionTreeRegressor()

# %%
y_predict = clf.predict(X_test)
y_predict
# Out:
# array([  6.9088, 157.1292,  -2.2758, ...,   0.5998,  21.7728,   7.209 ])

# %%
import numpy as np
from sklearn.metrics import accuracy_score, mean_squared_error, r2_score, classification_report
import matplotlib.pyplot as plt

# %%
plt.scatter(y_test, y_predict)
plt.xlabel("Actual Values")
plt.ylabel("Predicted Values")
plt.title("Predicted vs. Actual Values")
plt.show()

plt.scatter(y_predict, y_test - y_predict)  # Residual plot
plt.xlabel("Predicted Values")
plt.ylabel("Residuals")
plt.title("Residual Plot")
plt.show()
